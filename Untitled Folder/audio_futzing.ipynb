# %%
# %matplotlib notebook

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wavfile

# %%
path="/Users/Zaaron/Data/audio/ben_noah_5_23.wav"

# division time heurisitc in seconds
SILENCE = 0.5 #seconds
THRESHOLD = 50

rate, data = wavfile.read(path)

def contiguous_regions(condition):
    """Finds contiguous True regions of the boolean array "condition". Returns
    a 2D array where the first column is the start index of the region and the
    second column is the end index."""

    # Find the indicies of changes in "condition"
    d = np.diff(condition)
    idx, = d.nonzero() 

    # We need to start things after the change in "condition". Therefore, 
    # we'll shift the index by 1 to the right.
    idx += 1

    if condition[0]:
        # If the start of condition is True prepend a 0
        idx = np.r_[0, idx]

    if condition[-1]:
        # If the end of condition is True, append the length of the array
        idx = np.r_[idx, condition.size] # Edit

    # Reshape the result into two columns
    idx.shape = (-1,2)
    return idx

def divide_audio(audio, silence, rate, threshold=50):
    """
    creates division points for multi-channel audio based on silences
    silence is the min amount of silence
    """
    all_midpoints = []
    for channel in range(0, audio.shape[1]):
        silent_regions = contiguous_regions(audio[:, channel] < threshold)
        long_enough = (silent_regions[:,1] - silent_regions[:,0] > 2)
        # this is going to be an nx2 array of the long silent regions
        long_regions = silent_regions[long_enough, :]
        midpoints = list((long_regions[:,1]-long_regions[:,0])/2)
        all_midpoints.append(midpoints)
    return all_midpoints

all_midpoints = divide_audio(data[:,0:30000], SILENCE, rate)
print(len(all_midpoints[0]))
        
        
        
        
        
# data0 is the data from channel 0.

print("rate is:")
print(rate)
print("sample length - seconds:")
seconds = float(data.shape[0])/float(rate)
print(seconds)
minutes = (int(seconds) - int(seconds)%60)/60
print("sample length - minutes:")
print(minutes)
# Out:
# 708472
# rate is:
# 8000
# sample length - seconds:
# 3738.624
# sample length - minutes:
# 62.0

# %%
fig1=plt.figure(1)
plt.plot(data[0:50000,0])
#fig2=plt.figure(2)
plt.plot(data[0:50000,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig1=plt.figure(1)
plt.plot(data[50000:150000,0])
#fig2=plt.figure(2)
plt.plot(data[50000:150000,1])
plt.show()

# %%
fig1=plt.figure(1)
plt.plot(data[150000:300000,0])
#fig2=plt.figure(2)
plt.plot(data[150000:300000,1])
plt.show()

# %%
test = np.array([1, 10, 10, 10, 1, 10, 10, 1, 1, 10])

# %%
test > 5
# Out:
# array([False,  True,  True,  True, False,  True,  True, False, False,  True], dtype=bool)

# %%
np.diff(test > 5)
# Out:
# array([ True, False, False,  True,  True, False,  True, False,  True], dtype=bool)

# %%
def contiguous_regions(condition):
    """Finds contiguous True regions of the boolean array "condition". Returns
    a 2D array where the first column is the start index of the region and the
    second column is the end index."""

    # Find the indicies of changes in "condition"
    d = np.diff(condition)
    idx, = d.nonzero() 

    # We need to start things after the change in "condition". Therefore, 
    # we'll shift the index by 1 to the right.
    idx += 1

    if condition[0]:
        # If the start of condition is True prepend a 0
        idx = np.r_[0, idx]

    if condition[-1]:
        # If the end of condition is True, append the length of the array
        idx = np.r_[idx, condition.size] # Edit

    # Reshape the result into two columns
    idx.shape = (-1,2)
    return idx

# %%
out = contiguous_regions(test>5)

# %%
long_enough = (out[:,1] - out[:,0] > 2)
long_regions = out[long_enough,:]
midpoints = long_regions[:, 1] - long_regions[:,0]
print(midpoints)
print(out)
# Out:
# [3]
# [[ 1  4]
#  [ 5  7]
#  [ 9 10]]

# %%
test[3]
# Out:
# 10

# %%
test[4]
# Out:
# 1

# %%
def consecutive(data, stepsize=1):
    return np.split(data, np.where(np.diff(data) != stepsize)[0]+1)

a = np.array([0, 47, 48, 49, 50, 97, 98, 99])
test = consecutive(a)

# %%
test
# Out:
# [array([0]), array([47, 48, 49, 50]), array([97, 98, 99])]

# %%
np.mi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-e302ce08b43b> in <module>()
# ----> 1 np.mode(test[0])
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
import soundfile as sf
import os

# %%
DATA_FOLDER = '/Users/Zaaron/Data/audio/ben_noah_5_23_split/'

# %%
files = os.listdir(DATA_FOLDER)
all_data = []
for file in files:
    data,rate = sf.read("%s/%s"%(DATA_FOLDER, file))
    all_data.append(data)

# %%
fig1=plt.figure(1)
plt.title(files[4])
plt.plot(all_data[4])
fig2=plt.figure(3)
plt.title(files[5])
plt.plot(all_data[5])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
